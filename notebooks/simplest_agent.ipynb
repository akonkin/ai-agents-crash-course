# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI


dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
# %pip install openai-agents
# %pip install pydantic==2.11.9 pydantic-core==2.33.2
# Out:
# Requirement already satisfied: openai-agents in /opt/anaconda3/lib/python3.12/site-packages (0.6.6)
# Requirement already satisfied: griffe<2,>=1.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from openai-agents) (1.15.0)
# Requirement already satisfied: mcp<2,>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai-agents) (1.21.1)
# Requirement already satisfied: openai<3,>=2.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai-agents) (2.15.0)
# Requirement already satisfied: pydantic<3,>=2.12.3 in /opt/anaconda3/lib/python3.12/site-packages (from openai-agents) (2.12.5)
# Requirement already satisfied: requests<3,>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai-agents) (2.32.5)
# Requirement already satisfied: types-requests<3,>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai-agents) (2.32.4.20260107)
# Requirement already satisfied: typing-extensions<5,>=4.12.2 in /opt/anaconda3/lib/python3.12/site-packages (from openai-agents) (4.15.0)
# Requirement already satisfied: colorama>=0.4 in /opt/anaconda3/lib/python3.12/site-packages (from griffe<2,>=1.5.6->openai-agents) (0.4.6)
# Requirement already satisfied: anyio>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<2,>=1.11.0->openai-agents) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<2,>=1.11.0->openai-agents) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<2,>=1.11.0->openai-agents) (2.6.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<2,>=1.11.0->openai-agents) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.49.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.38.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai<3,>=2.9.0->openai-agents) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from openai<3,>=2.9.0->openai-agents) (0.12.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from openai<3,>=2.9.0->openai-agents) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.12/site-packages (from openai<3,>=2.9.0->openai-agents) (4.67.1)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=4.5->mcp<2,>=1.11.0->openai-agents) (3.7)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=2.12.3->openai-agents) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=2.12.3->openai-agents) (2.41.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.0->openai-agents) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.0->openai-agents) (2.5.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (0.22.3)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2,>=1.11.0->openai-agents) (1.1.0)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents) (2.21)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2,>=1.11.0->openai-agents) (8.2.1)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting pydantic==2.11.9
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic==2.11.9) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic==2.11.9) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic==2.11.9) (0.4.2)
# Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 6.9 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: pydantic-core, pydantic
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.5
#     Uninstalling pydantic_core-2.41.5:
#       Successfully uninstalled pydantic_core-2.41.5
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.5
#     Uninstalling pydantic-2.12.5:
#       Successfully uninstalled pydantic-2.12.5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pydantic]1/2 [pydantic]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openai-agents 0.6.6 requires pydantic<3,>=2.12.3, but you have pydantic 2.11.9 which is incompatible.
# aext-project-filebrowser-server 4.26.1 requires watchdog<5,>=4.0.1, but you have watchdog 6.0.0 which is incompatible.
# Successfully installed pydantic-2.11.9 pydantic-core-2.33.2
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """,
)

with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Bananas are a healthy, convenient fruit. They provide:
#
#     - Nutrients: potassium (about 400–450 mg per medium banana), vitamin C, vitamin B6, and some fiber.
#     - Fiber: helps digestion and fullness.
#     - Natural sugars: quick source of energy, with a moderate glycemic index (depends on ripeness).
#
#     Calories: ~105 per medium banana. Ripeness affects sugar content (riper = sweeter, higher GI slightly).
#
#     Who benefits: most people, including athletes for quick energy and mix-in for smoothies.
#
#     Notes:
#     - Diabetics should factor total carbs and glycemic load; portion the fruit.
#     - Not a allergy concern; otherwise fine for most.
#
#     Short tip: pair with protein or fats (e.g., peanut butter) for staying power.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)

# %% [markdown]
# _Good Job!_
